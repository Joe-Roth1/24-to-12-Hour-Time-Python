# %%
# take the input in military time
# integer input
import sys
print("Enter the hour in 24 hour time")
input_hour = (int(input())) 
if input_hour > 23 or input_hour < 0: # you cannot enter an hour above 23 or negatives
  sys.exit("Please enter a valid input")
print("Enter the minute in 24 hour time ")
input_minute = (int(input()))
if input_minute >59 or input_minute < 0: # you cannot enter a minute above 59 or negatives
 sys.exit("Please enter a valid input")

if input_hour == 0:
  new_hour=12
  if input_minute < 10:
    print(int(new_hour), ':' ,"0",int(input_minute),"AM")
  elif input_minute == 0:
    print(int(new_hour),":", int(input_minute), int(input_minute),"AM")
  else:
    print(int(new_hour),":",int(input_minute),"AM")

if input_hour == 12:
  new_hour=int(input_hour)
  if input_minute < 10:
    print(int(new_hour), ':' ,"0",int(input_minute),"PM")
  elif input_minute == 0:
    print(int(new_hour),":", int(input_minute), int(input_minute),"PM")
  else:
    print(int(new_hour),":",int(input_minute),"PM")


if input_hour >= 12:
  new_hour=int(input_hour)-12
  if input_minute <10:
    print(int(new_hour),":","0",int(input_minute),"PM")
  elif input_minute == 0:
    print(int(new_hour),":",int(input_minute),int(input_minute),"PM")
  else:
    print(int(new_hour),":",int(input_minute),"PM")


if input_hour < 12:
  if input_minute < 10:
    print(int(input_hour), ':' ,"0",int(input_minute),"AM")
  elif input_minute == 0:
    print(int(input_hour),":", int(input_minute), int(input_minute),"AM")
  else:
    print(int(input_hour),":",int(input_minute),"AM")
# Out:
# Enter the hour in 24 hour time
# 00
# Enter the minute in 24 hour time
# 00
# 12 : 0 0 AM
# 0 : 0 0 AM
